# %% [markdown]
# # Blade Element Force/ Moment Derivation

# %% [markdown]
# ### TODO
#     * model tail
#     * model motors
#     * model interaction of tail with wings when rotating

# %%
import sympy
import sympy.physics.mechanics as mech
import scipy.integrate
import numpy as np
import matplotlib.pyplot as plt
import collections
import os
sympy.init_printing()
sympy.physics.vector.init_vprinting()
# %matplotlib inline

# %%
phi, theta, psi, gamma, alpha_l, alpha, beta_l, beta, s, v_x, v_y, v_z, t = \
    sympy.symbols('phi, theta, psi, \gamma, alpha_l, alpha, beta_l, beta, s, v_x, v_y, v_z, t')
frame_i = mech.ReferenceFrame('i')
frame_b = frame_i.orientnew('b', 'Body', (psi(t), theta(t), phi(t)), '321')
frame_w = frame_b.orientnew('w', 'Body', (beta(t), alpha(t), 0), '321')
frame_f = frame_b.orientnew('f', 'Axis', (gamma(t), frame_b.x))
frame_l = frame_f.orientnew('l', 'Body', (-beta_l(t), -alpha_l(t), 0), '321')

# %%
point_cm = mech.Point('cm')
point_cm.set_vel(frame_b, frame_b.x*v_x + frame_b.y*v_y + frame_b.z*v_z)
point_p = point_cm.locatenew('p', -frame_f.y*s)
point_p.set_vel(frame_f, 0)

# %%
vel_p = point_p.v1pt_theory(point_cm, frame_b, frame_f)
vel_p
# Out:
# vₓ b_x + v_y b_y + v_z b_z - s⋅\gaṁma f_z

# %%
alpha_l_expr = sympy.atan(vel_p.dot(frame_f.z)/ vel_p.dot(frame_f.x))
alpha_l_expr
# Out:
#     ⎛-s⋅\gaṁma - v_y⋅sin(\gamma) + v_z⋅cos(\gamma)⎞
# atan⎜──────────────────────────────────────────────⎟
#     ⎝                      vₓ                      ⎠

# %%
beta_l_expr = sympy.atan(vel_p.dot(frame_f.y)/ vel_p.dot(frame_f.x))
beta_l_expr
# Out:
#     ⎛v_y⋅cos(\gamma) + v_z⋅sin(\gamma)⎞
# atan⎜─────────────────────────────────⎟
#     ⎝                vₓ               ⎠

# %%
vel_p.express(frame_b)
# Out:
# vₓ b_x + (s⋅sin(\gamma)⋅\gaṁma + v_y) b_y + (-s⋅cos(\gamma)⋅\gaṁma + v_z) b_z

# %%
CL_alpha = sympy.Symbol('C_L_alpha')
CD_0 = sympy.Symbol('C_D_0')
CL_DM = sympy.Symbol('C_L_DM')
CL_0 = sympy.Symbol('C_L_0')
c_bar = sympy.Symbol('c_bar')
CL_alpha, c_bar
# Out:
# (C_L_α, c_bar)

# %%
CL = CL_alpha*alpha_l(t) + CL_0
CL
# Out:
# C_L_0 + C_L_α⋅α_l

# %%
k, rho, S = sympy.symbols('k, rho, S')
CD = k*(CL - CL_DM)**2 + CD_0
CD
# Out:
#                                       2
# C_D_0 + k⋅(C_L_0 - C_L_DM + C_L_α⋅α_l)

# %%
q = rho*vel_p.dot(vel_p)/2
q
# Out:
#   ⎛ 2        2
# ρ⋅⎝s ⋅\gaṁma  + s⋅v_y⋅sin(\gamma)⋅\gaṁma - s⋅v_z⋅cos(\gamma)⋅\gaṁma - s⋅(-v
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      2
#
#                                               2      2      2⎞
# _y⋅sin(\gamma) + v_z⋅cos(\gamma))⋅\gaṁma + vₓ  + v_y  + v_z ⎠
# ──────────────────────────────────────────────────────────────

# %%
L = -CL*q*c_bar*frame_l.z
L
# Out:
#                              ⎛ 2        2
# c_bar⋅ρ⋅(-C_L_0 - C_L_α⋅α_l)⋅⎝s ⋅\gaṁma  + s⋅v_y⋅sin(\gamma)⋅\gaṁma - s⋅v_z⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                          2
# cos(\gamma)⋅\gaṁma - s⋅(-v_y⋅sin(\gamma) + v_z⋅cos(\gamma))⋅\gaṁma + vₓ  + v
# ──────────────────────────────────────────────────────────────────────────────
#      2
#
#   2      2⎞
# _y  + v_z ⎠
# ───────────
#             l_z

# %%
D = -CD*q*c_bar*frame_l.x
D
# Out:
#         ⎛                                       2⎞ ⎛ 2        2
# c_bar⋅ρ⋅⎝-C_D_0 - k⋅(C_L_0 - C_L_DM + C_L_α⋅α_l) ⎠⋅⎝s ⋅\gaṁma  + s⋅v_y⋅sin(\g
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# amma)⋅\gaṁma - s⋅v_z⋅cos(\gamma)⋅\gaṁma - s⋅(-v_y⋅sin(\gamma) + v_z⋅cos(\gam
# ──────────────────────────────────────────────────────────────────────────────
#                 2
#
#                  2      2      2⎞
# ma))⋅\gaṁma + vₓ  + v_y  + v_z ⎠
# ─────────────────────────────────
#                                   l_x

# %%
F_A = L + D
F_A_b = sympy.Matrix([
    F_A.dot(frame_b.x),
    F_A.dot(frame_b.y),
    F_A.dot(frame_b.z)]).subs({alpha_l(t):alpha_l_expr, beta_l(t): beta_l_expr})

# %%
x_ac = sympy.Symbol('x_ac')
M_A = (-x_ac*frame_b.x + s*frame_f.y).cross(F_A)
M_A_b = sympy.Matrix([M_A.dot(frame_b.x),
         M_A.dot(frame_b.y),
         M_A.dot(frame_b.z)]).subs({alpha_l(t):alpha_l_expr, beta_l(t): beta_l_expr})

# %%
def compute_aero(f_F_A_b, f_M_A_b, gamma_val, gamma_dot_val, const):
    """
    Given state of aircraft, computes instantaenous aerodynamic force.
    """
    span = const['span']
        
    ode_f_left = scipy.integrate.ode(lambda s: f_F_A_b(s, gamma_val, gamma_dot_val))
    ode_f_left.set_initial_value([0,0,0], 0)
    ode_f_left.integrate(span/2.0)
    F_left = ode_f_left.y
    
    F_right = np.array([F_left[0], -F_left[1], F_left[2]])
    
    ode_m_left = scipy.integrate.ode(lambda s: f_M_A_b(s, gamma_val, gamma_dot_val))
    ode_m_left.set_initial_value([0,0,0], 0)
    ode_m_left.integrate(span/2.0)
    M_left = ode_m_left.y
    
    M_right = np.array([-M_left[0], M_left[1], M_left[2]])

    F_b = F_left + F_right
    M_b = M_left + M_right
    return F_b, M_b

# %%
def gen_aero_force_moment_funcs(F_A_b, M_A_b, const):
    # generate a fast function to find the aero force
    gam, gam_dot = sympy.symbols('gam, gam_dot')
    state_sub = {gamma(t).diff(t):gam_dot, gamma(t):gam}
    f_F_A_b = sympy.lambdify((s, gam, gam_dot), F_A_b.subs(const).subs(state_sub))
    f_M_A_b = sympy.lambdify((s, gam, gam_dot), M_A_b.subs(const).subs(state_sub))
    return f_F_A_b, f_M_A_b

# %%
def calc_aero_forces(freq, F_A_b, M_A_b, const):
    """
    Computes force history due to flapping motion of wing.
    """
    # generate a fast function to find the aero force
    f_F_A_b, f_M_A_b = gen_aero_force_moment_funcs(F_A_b, M_A_b, const)
    
    # figure out a period to plot over
    if freq == 0:
        t_vect = np.linspace(0,1,200)
    else:
        t_vect = np.linspace(0,1.0/freq,200)
    gamma_vect = np.sin(2*np.pi*freq*t_vect)
    gamma_dvect = 2*np.pi*freq*np.cos(2*np.pi*freq*t_vect)
    
    # do simulation
    n = len(gamma_vect)
    F_b_vect = np.zeros((n,3))
    M_b_vect = np.zeros((n,3))
    for i in range(len(gamma_vect)):
        gamma_val = gamma_vect[i]
        gamma_dot_val  = gamma_dvect[i]
        F_b, M_b = compute_aero(f_F_A_b, f_M_A_b, gamma_val, gamma_dot_val, const)
        F_b_vect[i,:] = F_b
        M_b_vect[i,:] = M_b
    
    return t_vect, gamma_vect, F_b_vect, M_b_vect

# %%
def plot_aero_force_moment(t, gamma, F_b, M_b):
    """
    Plots aerodynamic force history.
    """
    plt.figure(figsize=(10,10))
    plt.subplot(311)
    plt.plot(t, gamma)
    #plt.xlabel('t, sec')
    plt.ylabel(r'$\gamma$')
    plt.title('wing movement')
    plt.grid()
    
    lift = -F_b[:,2]
    side = -F_b[:,1]
    thrust = F_b[:,0]
    
    plt.subplot(312)
    newton_to_grams = 1.0e3/9.8
    plt.plot(t_vect, lift*newton_to_grams)
    plt.plot(t_vect, thrust*newton_to_grams)
    plt.plot(t_vect, side*newton_to_grams)
    plt.legend(['lift', 'thrust', 'side'])
    #plt.xlabel('t, sec')
    plt.ylabel('gm')
    plt.title('aerodynamic forces')
    plt.grid()
    
    plt.subplot(313)
    newton_m_to_gram_cm = 1.0e4/9.8
    plt.plot(t_vect, M_b*newton_m_to_gram_cm)
    plt.legend(['roll', 'pitch', 'yaw'])
    plt.xlabel('t, sec')
    plt.ylabel('gm-cm')
    plt.title('aerodynamic moments')
    plt.grid()

# %% [markdown]
# # Wind Tunnel Data for SR-1 Robotic Bird

# %%
class TunnelRecord(collections.namedtuple('TunnelRecordData',
    ['time_stamp', 'temp_C', 'dynamic_pressure_Pa',
     'velocity_m_per_sec', 'drag_N', 'lift_N',
     'side_N', 'pitch_N_m', 'roll_N_m', 'yaw_N_m',
     'aoa_rad'])):

        
    @classmethod
    def load(cls, path, skip=[]):
        # conversion factors
        in_h20_to_Pa = 249
        lbs_to_N = 4.44822162825
        ft_lbs_to_N_m = 1.35581795
        
        # read file
        with open(path) as f:
            lines = f.readlines()
        new_lines = []
        for i in range(len(lines)):
            if i in skip:
                continue
            new_lines.append(lines[i].strip().split('\t'))
        new_lines = np.array(new_lines).T
        time_stamp = new_lines[0,:]
        data = new_lines[1:,:].astype(float)
        
        # convert and create data structure
        return cls(
            time_stamp=time_stamp,
            temp_C=data[0,:],
            dynamic_pressure_Pa=data[1,:]*in_h20_to_Pa,
            velocity_m_per_sec=data[2,:],
            drag_N=data[3,:]*lbs_to_N,
            lift_N=-data[4,:]*lbs_to_N,
            side_N=data[5,:]*lbs_to_N,
            roll_N_m=data[6,:]*ft_lbs_to_N_m,
            pitch_N_m=data[7,:]*ft_lbs_to_N_m,
            yaw_N_m=data[8,:]*ft_lbs_to_N_m,
            aoa_rad=np.deg2rad(data[9,:]))

# %%
class AeroCoefficients(collections.namedtuple('AeroCoefficientsData',
    ['aoa_rad', 'S', 'b', 'CL', 'CD', 'CY', 'Cl', 'Cm', 'Cn'])):

    @classmethod
    def from_TunnelRecord(cls, tr, S, b):
        CL = tr.lift_N/tr.dynamic_pressure_Pa/S
        CD = tr.drag_N/tr.dynamic_pressure_Pa/S
        CY = tr.side_N/tr.dynamic_pressure_Pa/S
        # TODO proper non-dim for moments
        Cl = tr.roll_N_m/tr.dynamic_pressure_Pa/S/b
        Cm = tr.pitch_N_m/tr.dynamic_pressure_Pa/S/b
        Cn = tr.yaw_N_m/tr.dynamic_pressure_Pa/S/b
        aoa_rad = tr.aoa_rad
        return cls(aoa_rad=aoa_rad, S=S, b=b, CL=CL, CD=CD, CY=CY, Cl=Cl, Cm=Cm, Cn=Cn)
    
    def subtract(self, mounts_ac):
        return AeroCoefficients(
            aoa_rad=self.aoa_rad, S=self.S, b=self.b,
            CL=self.CL - mounts_ac.CL.mean(),
            CD=self.CD - mounts_ac.CD.mean(),
            CY=self.CY - mounts_ac.CY.mean(),
            Cl=self.Cl - mounts_ac.Cl.mean(),
            Cm=self.Cm - mounts_ac.Cm.mean(),
            Cn=self.Cn - mounts_ac.Cn.mean())
    
    def fit(self):
        k_CD_CL, b, c = np.polyfit(self.CL, self.CD, 2)
        CL_DM = -b/(2*k_CD_CL)
        CD_0 = c - k_CD_CL*CL_DM**2
        CL_alpha, CL_0 = np.polyfit(self.aoa_rad, self.CL, 1)
        Cl_alpha = np.polyfit(self.aoa_rad, self.Cl, 1)[0]
        Cm_alpha = np.polyfit(self.aoa_rad, self.Cm, 1)[0]
        Cn_alpha = np.polyfit(self.aoa_rad, self.Cn, 1)[0]
        return {
            'CL_DM': CL_DM,
            'CD_0': CD_0,
            'k_CD_CL': k_CD_CL,
            'CL_0': CL_0,
            'CL_alpha': CL_alpha,
            'Cl_alpha': Cl_alpha,
            'Cm_alpha': Cm_alpha,
            'Cn_alpha': Cn_alpha}
    
    def plot(self):
        aoa_deg = np.rad2deg(self.aoa_rad)
        
        plt.figure(figsize=(15,5))
        
        plt.subplot(131)
        plt.plot(aoa_deg, self.CL, '.')
        plt.xlabel(r'$\alpha$, deg')
        plt.ylabel('CL')
        plt.grid()
        
        plt.subplot(132)
        plt.plot(self.CL, self.CD, '.')
        plt.xlabel('CL')
        plt.ylabel('CD')
        plt.grid()
        
        plt.subplot(133)
        h = []
        h.append(plt.plot(aoa_deg, self.Cl, '.')[0])
        h.append(plt.plot(aoa_deg, self.Cm, '.')[0])
        h.append(plt.plot(aoa_deg, self.Cn, '.')[0])
        plt.legend(h, ['Cl', 'Cm', 'Cn'], loc='best')
        plt.xlabel(r'$\alpha$, deg')
        plt.ylabel('Cl, Cm, Cn')
        plt.grid()

# %%
plt.rcParams['lines.markersize']= 10
plt.rcParams['font.size']= 12
S = 0.35 # reference area
b = 0.6 # span

# %%
tr_mounts = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'camflyer062814mountscont_.txt'), skip=[0])
ac_mounts = AeroCoefficients.from_TunnelRecord(tr_mounts, S, b)

# %%
tr = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'FlappingWing1.txt'), skip=[0])
ac = AeroCoefficients.from_TunnelRecord(tr, S, b)
ac = ac.subtract(ac_mounts)
ac.plot()
tr_glide = tr
glide_fit = ac.fit()
glide_fit
# Out:
# {'CD_0': 0.053674633868212168,
#  'CL_0': 0.099598674209744054,
#  'CL_DM': 0.1353688204500561,
#  'CL_alpha': 1.7610242115963182,
#  'Cl_alpha': -1.3183008196267691,
#  'Cm_alpha': 0.1598954562961796,
#  'Cn_alpha': -4.7178736594220672,
#  'k_CD_CL': 0.3345291353136095}

# %%
tr = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'FlappingWing_roll_left.txt'))
ac = AeroCoefficients.from_TunnelRecord(tr, S, b)
ac = ac.subtract(ac_mounts)
ac.plot();
ac.fit()
# Out:
# {'CD_0': 0.059171369292116964,
#  'CL_0': 0.072752784155467654,
#  'CL_DM': 0.10584876607741232,
#  'CL_alpha': 1.1442807812510465,
#  'Cl_alpha': -1.4078193402641708,
#  'Cm_alpha': -0.078388693422033112,
#  'Cn_alpha': -16.355402628335206,
#  'k_CD_CL': 0.56360528328344273}

# %%
tr = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'FlappingWing_roll_right.txt'))
ac = AeroCoefficients.from_TunnelRecord(tr, S, b)
ac = ac.subtract(ac_mounts)
ac.plot();
ac.fit()
# Out:
# {'CD_0': 0.065426383329440313,
#  'CL_0': 0.030517230428125573,
#  'CL_DM': 0.082337206184180542,
#  'CL_alpha': 1.1023502820706819,
#  'Cl_alpha': -1.4113100636755336,
#  'Cm_alpha': -0.18332189010993694,
#  'Cn_alpha': 8.5506830093162218,
#  'k_CD_CL': 0.50417555041035167}

# %%
tr = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'FlappingWing_wings_up.txt'))
ac = AeroCoefficients.from_TunnelRecord(tr, S, b)
ac = ac.subtract(ac_mounts)
ac.plot();
ac.fit()
# Out:
# {'CD_0': 0.078200400730167458,
#  'CL_0': 0.032731661386622889,
#  'CL_DM': 0.035472886299610491,
#  'CL_alpha': 0.89547475485620731,
#  'Cl_alpha': -1.4198186756609996,
#  'Cm_alpha': 0.202398872395331,
#  'Cn_alpha': -6.2191790797932729,
#  'k_CD_CL': 0.62573133564490435}

# %%
tr = TunnelRecord.load(
    os.path.join('flapping-wing',
                 'FlappingWing_wings_down.txt'))
ac = AeroCoefficients.from_TunnelRecord(tr, S, b)
ac = ac.subtract(ac_mounts)
ac.plot();
ac.fit()
# Out:
# {'CD_0': 0.063514087354008944,
#  'CL_0': 0.10598117527784996,
#  'CL_DM': 0.17888805184485052,
#  'CL_alpha': 1.5806477175604186,
#  'Cl_alpha': -1.2546690059856509,
#  'Cm_alpha': 0.24985262178792367,
#  'Cn_alpha': -1.7547348483234457,
#  'k_CD_CL': 0.41782991271601944}

# %% [markdown]
# # Flapping Simulation

# %%
glide_fit
# Out:
# {'CD_0': 0.053674633868212168,
#  'CL_0': 0.099598674209744054,
#  'CL_DM': 0.1353688204500561,
#  'CL_alpha': 1.7610242115963182,
#  'Cl_alpha': -1.3183008196267691,
#  'Cm_alpha': 0.1598954562961796,
#  'Cn_alpha': -4.7178736594220672,
#  'k_CD_CL': 0.3345291353136095}

# %%
v_tunnel = np.sqrt(tr_glide.dynamic_pressure_Pa*2/1.225).mean() # velocity of vehicle, m/s
v = 9
alpha = 20*np.pi/180 # angle of attack of vehcile
freq = 5 # frequency of wing flap, Hz
const = {CL_alpha:glide_fit['CL_alpha'], rho:1.225, v_x:v*np.cos(alpha), v_y:0, v_z:v*np.sin(alpha),
         c_bar:0.1, k:glide_fit['k_CD_CL'], CD_0:glide_fit['CD_0'],
         CL_0:glide_fit['CL_0'], CL_DM:glide_fit['CL_DM'], 'span':0.58, 'x_ac': 0.05}
t_vect, gamma_vect, F_b, M_b = calc_aero_forces(freq, F_A_b, M_A_b, const)

# %%
plot_aero_force_moment(t_vect, gamma_vect, F_b, M_b)

# %% [markdown]
# By adjusting the velocity, we see that when flapping at 5 Hz, the top velocit of the vehicle is 6 m/s since the thrust approaches zero.

# %%
newtons_to_gm = 1000/9.8
newton_m_to_gm_cm = 1.0e4/9.8
F_b_mean = F_b.mean(0)*newtons_to_gm
M_b_avg_gm_cm = M_b.mean(0)*newton_m_to_gm_cm
lift_avg_gm = -F_b_mean[2]
side_avg_gm = F_b_mean[1]
thrust_avg_gm = F_b_mean[0]
print 'lift:\t{:10.2f} gm\nside:\t{:10.2f} gm\nthrust:\t{:10.2f} gm'.format(
    lift_avg_gm, side_avg_gm, thrust_avg_gm)
print 'roll:\t{:10.2f} gm-cm\npitch:\t{:10.2f} gm-cm\nyaw:\t{:10.2f} gm-cm'.format(
    M_b_avg_gm_cm[0], M_b_avg_gm_cm[1], M_b_avg_gm_cm[2])
# Out:
# lift:	    185.95 gm
# side:	      0.00 gm
# thrust:	     67.27 gm
# roll:	      0.00 gm-cm
# pitch:	    -92.97 gm-cm
# yaw:	   -123.15 gm-cm

# %% [markdown]
# ## Payload Budget

# %% [markdown]
# In steady state conditions we rotate the lift and thrust to the local tangent frame to see if it cancels the weight and drag. The thrsut is about zero, cancelling the drag, when the velocity is 9 m/s which seems too high. The lift generated is also insufficient for the size of the bird. Therefore, the aerodynamics need to be improved.

# %%
-lift_avg_gm*np.sin(alpha) + thrust_avg_gm*np.cos(alpha)
# Out:
# -0.381961528761

# %%
mass_gm = 300
lift_avg_gm*np.cos(alpha) + thrust_avg_gm*np.sin(alpha) - mass_gm
# Out:
# -102.257521326

# %% [markdown]
# We are currently not able to genearte enough lift with the SR-1 to lift our entire package.

# %% [markdown]
# ## Testing Aerodynamics Calculation Speed

# %%
f_F_A_b, f_M_A_b = gen_aero_force_moment_funcs(F_A_b, M_A_b, const)

# %%
# %%timeit
compute_aero(f_F_A_b, f_M_A_b, 1, 1, const)
# Out:
# 100 loops, best of 3: 2.06 ms per loop
